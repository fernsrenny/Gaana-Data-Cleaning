# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 328, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 328 (delta 19), reused 54 (delta 9), pack-reused 235 (from 1)
# Receiving objects: 100% (328/328), 278.62 MiB | 16.88 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# Updating files: 100% (225/225), done.

# %%
import pandas as pd

df = pd.read_csv('/content/datasets/Gaana/songs.csv')

df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language
# 0                 /dil-e-nadan-tujhe-3     Urdu
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu
# 2                       /unke-dekhe-se     Urdu
# ...

# %% [markdown]
# ##Exploring the data
#
# ####1.1) Checking null values

# %%
df.isnull().sum()
# Out:
# name         0
# singer       0
# singer_id    0
# duration     0
# link         0
# language     0
# dtype: int64

# %% [markdown]
# ####1.2) Checking duplicates

# %%
len(df)==df['link'].nunique
# Out:
# False

# %%
len(df) - df['link'].nunique()
# Out:
# 4994

# %%
df[df.duplicated('link')]['language'].value_counts()
# Out:
# language
# Old       4993
# Telugu       1
# Name: count, dtype: int64

# %%
df['language'].value_counts()
# Out:
# language
# Telugu        4996
# Hindi         4993
# Old           4993
# Marathi       4699
# Tamil         4677
# Punjabi       3818
# Kannada       3559
# Urdu          3116
# Gujarati      2115
# Bengali        958
# Odia           940
# Assamese       724
# Rajasthani     541
# Bhojpuri       519
# Malayalam      479
# Haryanvi       228
# Name: count, dtype: int64

# %% [markdown]
# ####1.3) Removing duplicates

# %%
df.drop_duplicates(subset = 'link', inplace = True)

# %%
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df['language'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='language'>

# %%
df.describe()
# Out:
#             name                  singer                      singer_id  \
# count      36361                   36361                          36361
# unique     31534                    6196                           6580
# top     Padhyams  S. P. Balasubrahmanyam  /artist/s-p-balasubrahamanyam
# freq          20                    1151                           1155
#
#        duration                  link language
# count     36361                 36361    36361
# unique     1309                 36361       15
# top       03:02  /dil-e-nadan-tujhe-3   Telugu
# freq        417                     1     4995

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36361 entries, 0 to 41354
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   name       36361 non-null  object
#  1   singer     36361 non-null  object
#  2   singer_id  36361 non-null  object
#  3   duration   36361 non-null  object
#  4   link       36361 non-null  object
#  5   language   36361 non-null  object
# dtypes: object(6)
# memory usage: 1.9+ MB

# %%
df.value_counts()
# Out:
# name                         singer                              singer_id                                          duration  link                                  language
# (Ami) Takdum Takdum Bajai    S. D. Burman                        /artist/sdburman                                   03:07     /-ami-takdum-takdum-bajai             Bengali     1
# Noor-e-Nabi Qandil           Khursheed Ahmed                     /artist/khursheed-ahmed                            07:13     /noor-e-nabi-qandil                   Urdu        1
# Non Stop Entertainment       Jagmohan Kaur|K. Deep               /artist/jagmohan-kaur|/artist/k-deep-1             20:45     /non-stop-entertainment-live-part-ii  Punjabi     1
# Nookalammanu Nenu            L.R. Eswari|S. P. Balasubrahmanyam  /artist/lr-eswari-2|/artist/s-p-balasubrahamanyam  04:15     /nookalammanu-nenu                    Telugu      1
# ...

# %%
df.columns
# Out:
# Index(['name', 'singer', 'singer_id', 'duration', 'link', 'language'], dtype='object')

# %%
df.columns[1:3]
# Out:
# Index(['singer', 'singer_id'], dtype='object')

# %%
df.shape
# Out:
# (36361, 6)

# %%
df.min
# Out:
# <bound method DataFrame.min of                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...

# %%
df['singer'].value_counts().head(10)
# Out:
# singer
# S. P. Balasubrahmanyam                1151
# Asha Bhosle                           1037
# P. Susheela                           1019
# Lata Mangeshkar                        856
# S. Janaki                              728
# Mohammed Rafi                          698
# S. P. Balasubrahmanyam|P. Susheela     682
# Kishore Kumar                          663
# Noor Jehan                             489
# S. P. Balasubrahmanyam|S. Janaki       455
# Name: count, dtype: int64

# %% [markdown]
# ####1.4) Finding number of singers collaborated

# %%
df['no_of_singers']= df['singer'].str.split('|').str.len()
df
# Out:
#                                                     name  \
# 0                                  Dil - E - Nadan Tujhe
# 1                      Agar Hum Kahen Aur Woh Muskara De
# 2                                          Unke Dekhe Se
# 3                Yeh Na Thi Hamari Qismat - Chitra Singh
# 4                                Hazaron Khwahishen Aisi
# ...                                                  ...
# 41350  Chaaridike Paaper Andhar (Manush Janam Diye Bi...
# 41351                                Ei Ki Go Shesh Daan
# 41352                                       Ei Je Bangla
# 41353                               Jatone Hridaye Rekho
# 41354                            Tomar Je Oi Haater Mala
#
#                                singer  \
# 0           Chitra Singh|Jagjit Singh
# 1           Chitra Singh|Jagjit Singh
# 2                        Jagjit Singh
# 3                        Chitra Singh
# 4                        Jagjit Singh
# ...                               ...
# ...

# %%
df.sort_values(by = 'no_of_singers', ascending = False).head(1)
# Out:
#                                           name  \
# 41048  Neel Kamal Lal Kamal - Thakurmaar Jhuli
#
#                                                   singer  \
# 41048  Asha Devi|Kazi Sabyasachi|Lalita Dhar Chowdhur...
#
#                                                singer_id duration  \
# 41048  /artist/asha-devi|/artist/kazi-sabyasachi|/art...    18:41
#
#                          link language  no_of_singers
# 41048  /neel-kamal-laal-kamal  Bengali             25

# %% [markdown]
# ####1.5) Creating duration column

# %%
duration = []
for i in df['duration']:

  if len(i.split(':'))==2:
    minutes = int(i.split(':')[0])
    seconds = int(i.split(':')[1])
    duration.append(minutes*60 + seconds)
  else:
    hours = int(i.split(':')[0])
    minutes = int(i.split(':')[1])
    seconds = int(i.split(':')[2])
    duration.append(hours*3600 + minutes*60 + seconds)

df['duration_in_seconds'] = duration

df.head()
# Out:
#                                       name                     singer  \
# 0                    Dil - E - Nadan Tujhe  Chitra Singh|Jagjit Singh
# 1        Agar Hum Kahen Aur Woh Muskara De  Chitra Singh|Jagjit Singh
# 2                            Unke Dekhe Se               Jagjit Singh
# 3  Yeh Na Thi Hamari Qismat - Chitra Singh               Chitra Singh
# 4                  Hazaron Khwahishen Aisi               Jagjit Singh
#
#                                       singer_id duration  \
# 0  /artist/chitra-singh|/artist/jagjeet-singh-1    05:00
# 1  /artist/chitra-singh|/artist/jagjeet-singh-1    06:26
# 2                       /artist/jagjeet-singh-1    03:41
# 3                          /artist/chitra-singh    04:26
# 4                       /artist/jagjeet-singh-1    05:39
#
#                                   link language  no_of_singers  \
# 0                 /dil-e-nadan-tujhe-3     Urdu              2
# 1  /agar-hum-kahen-aur-woh-muskura-den     Urdu              2
# ...

# %%
df.sort_values(by = 'duration_in_seconds', ascending= False)
# Out:
#                                             name  \
# 16093                                 Haye Tumba
# 16352                             Bum Bum Lahiri
# 15000                             Bum Bum Lahiri
# 15025                       Kanu Atharu Bahoundi
# 14624               Desi Bandri Vilayati Cheekan
# ...                                          ...
# 9480                   Sppech By Sabapathipillai
# 36778  Introduction Telegu Films Idi Mallelavela
# 6500                                   Dialogues
# 35561       Title Musics - Jagadekaveeruni Katha
# 22952  Dialogues (Ghulami): Aahi Jaana Mere Liye
#
#                                                   singer  \
# 16093                                     Dilshad Akhtar
# 16352                                     Dilshad Akhtar
# 15000                                     Dilshad Akhtar
# 15025                                     Dilshad Akhtar
# 14624                                     Dilshad Akhtar
# ...

# %%
# 1. Number of Songs in Hindi | 4993
print(len(df[df['language'] == 'Hindi']))

# 2. Singles by Jagjit Singh
print(len(df[df['singer'] == 'Jagjit Singh']))

# 3. Total Unique Songs
print(df['link'].nunique())

# 4. Language with maximum songs
print(df['language'].value_counts().sort_values(ascending = False).head(1).index[0])

# 5. Singer with Maximum Solo
print(df['singer'].value_counts().idxmax())

# 6. Solo Urdu songs by Jagjit Singh
print(len(df[(df['language'] == 'Urdu') & (df['singer'] == 'Jagjit Singh')]))

# 7. Average Duration of Hindi Songs
duration = int(df[df['language'] == 'Hindi']['duration_in_seconds'].mean())
print(duration//60, "min",duration % 60, "sec")

# 8. Total Songs of Jagjit Singh
c = 0
for singers in df['singer']:
  if 'Jagjit Singh' in singers.split('|'):
    c += 1
print(c)

# 9. Singer with Maximum Songs in Total
print(df['singer'].str.split('|').explode().value_counts().idxmax())

# 10. Song with Maximum Singers Collaborated
df.sort_values(by = 'no_of_singers', ascending = False).head(1)

# 11. Language with Maximum average song length
df.groupby('language')['duration_in_seconds'].mean().idxmax()
# Out:
# 4993
# 120
# 36361
# Telugu
# S. P. Balasubrahmanyam
# 40
# 5 min 10 sec
# 184
# S. P. Balasubrahmanyam
# 'Punjabi'

# %%
(df['singer'].str.split('|').explode() == 'Jagjit Singh').sum()
# Out:
# 184

# %%
df.groupby('language')['duration_in_seconds'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='language'>

# %%
df.groupby('language')['duration_in_seconds'].max().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='language'>

# %%
df.groupby('language')['duration_in_seconds'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='language'>
